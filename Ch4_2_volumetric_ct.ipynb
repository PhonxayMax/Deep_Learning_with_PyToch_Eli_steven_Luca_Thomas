# %% [markdown]
# <a href="https://colab.research.google.com/github/PhonxayMax/Deep_Learning_with_PyToch_Eli_steven_Luca_Thomas/blob/main/Ch4_2_volumetric_ct.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import torch
torch.set_printoptions(edgeitems=2, threshold=50)

# %%
import imageio

dir_path = "/content/volumetric-dicom"
vol_arr = imageio.volread(dir_path, 'DICOM')
vol_arr.shape
# Out:
# 99/99 files (100.0%)
#   Found 1 correct series.
# Reading DICOM (loading data): 99/99  (100.0%)
# (99, 512, 512)

# %%
vol = torch.from_numpy(vol_arr).float()
vol = torch.unsqueeze(vol, 0)

vol.shape
# Out:
# torch.Size([1, 99, 512, 512])

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

plt.imshow(vol_arr[50])
plt.imshow(vol_arr[25])
